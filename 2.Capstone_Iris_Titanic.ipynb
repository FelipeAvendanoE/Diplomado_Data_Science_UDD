# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeAvendanoE/Diplomado_Data_Science_UDD/blob/main/2.Capstone_Iris_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Obtención y preparación de datos**
#
# # OD27. Proyecto Final
#
# Normalmente, los proyectos de ciencia de datos, comienzan con estadísticas descriptivas para tener una idea de las propiedades del conjunto de datos que se está trabajando. Afortunadamente, es fácil obtener estas estadísticas con las estructuras de datos de **Pandas**.

# %% [markdown]
# ## <font color='blue'>**Estadística Descriptiva con la Base de Datos Iris**</font>
#
# En este proyecto, deberán implemnetar el cálculo de varias estadísticas descriptivas para el clásico <a href="https://en.wikipedia.org/wiki/Iris_flower_data_set">conjunto de datos de iris</a>.
#
# El siguiente código, carga los paquetes necesarios y también el conjunto de datos iris.
#
# `load_iris()` carga en un objeto que contiene el conjunto de datos de iris.

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_iris

iris_obj = load_iris()

# %% [markdown]
# Obtendremos un objeto del tipo __Bunch__, el cual es un contenedor de datos a los cuales se accede a través de _llaves_, de forma similar que en un diccionario de Python.

# %%
type(iris_obj)
# Out:
# sklearn.utils._bunch.Bunch

# %%
iris_obj.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print(type(iris_obj['data']), '\n')
iris_obj['data']
# Out:
# <class 'numpy.ndarray'>
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %% [markdown]
# ### <font color='green'>Actividad 1</font>
#
# Basado en la estructura del objeto **iris_obj**, convierta este en un dataframe.

# %%
# Tu código aquí ...
df = load_iris(return_X_y=True, as_frame=True)

# %%
# Observamos que df corresponde a una tupla.
type(df)
# Out:
# tuple

# %%
df
# Out:
# (     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
#  0                  5.1               3.5                1.4               0.2
#  1                  4.9               3.0                1.4               0.2
#  2                  4.7               3.2                1.3               0.2
#  3                  4.6               3.1                1.5               0.2
#  4                  5.0               3.6                1.4               0.2
#  ..                 ...               ...                ...               ...
#  145                6.7               3.0                5.2               2.3
#  146                6.3               2.5                5.0               1.9
#  147                6.5               3.0                5.2               2.0
#  148                6.2               3.4                5.4               2.3
#  149                5.9               3.0                5.1               1.8
#
#  [150 rows x 4 columns],
#  0      0
#  1      0
#  2      0
#  3      0
#  4      0
#        ..
#  145    2
#  146    2
#  147    2
#  148    2
#  149    2
#  Name: target, Length: 150, dtype: int64)

# %%
# Observamos que df corresponde a una tupla donde el primer elemento corresponde a las observaciones.
# El segundo elemento corresponde a la clasificación
df_data = df[0]
df_target = df[1]

# %%
# Unimos ambos en un unico df
df_total = df_data.merge(right=df_target, left_index = True, right_index = True )

# %% [markdown]
# <font color='green'>Fin Actividad 1</font>

# %% [markdown]
# ### <font color='green'>Actividad 2</font>
#
# 1. Reemplace los valores de la columna "species" por los siguientes valores:
#   * "setosa" = 0
#   * "versicolor" = 1
#   * "virginica" = 2
#
# 2. Agrupe las muestras por especies
# 3. Sin usar el método `describe` calcule los estadísticos básicos de la muestra:
#   * cantidad de elementos no nulos
#   * media
#   * varianza
#   * Desviación estándar
#   * Percentiles y cuartiles
#   * Rango inter-cuartílico
#   * Valores máximos y mínimos
#   * Rango (diferencia entre el máximo y el mínimo)
# 4. Repita algunos de los análisis anteriores, pero muestre sus resultados por columnas y especies.
# 5. Compare sus resultados usando el metodo `describe` por columnas y por especies
# 6. Generar una tabla multi-indice por "especies" y "ancho del pétalo" y que de cuenta de la suma de los valores de cada clase

# %%
df_total
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
# 1
df_total['target'].replace(to_replace=0, value = 'setosa', inplace = True)

# %%
df_total['target'].replace(to_replace=1, value = 'versicolor', inplace = True)

# %%
df_total['target'].replace(to_replace=2, value = 'virginica', inplace = True)

# %%
df_total
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
# 2 y 3
df_total.groupby('target').count()
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                     50                50                 50
# versicolor                 50                50                 50
# virginica                  50                50                 50
#
#             petal width (cm)
# target
# setosa                    50
# versicolor                50
# virginica                 50

# %%
df_total.groupby('target').mean()
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# target
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %%
df_total.groupby('target').std()
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa               0.352490          0.379064           0.173664
# versicolor           0.516171          0.313798           0.469911
# virginica            0.635880          0.322497           0.551895
#
#             petal width (cm)
# target
# setosa              0.105386
# versicolor          0.197753
# virginica           0.274650

# %%
q3 = df_total.groupby('target').quantile(0.75)

# %%
q3
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                    5.2             3.675              1.575
# versicolor                6.3             3.000              4.600
# virginica                 6.9             3.175              5.875
#
#             petal width (cm)
# target
# setosa                   0.3
# versicolor               1.5
# virginica                2.3

# %%
q1 = df_total.groupby('target').quantile(0.25)

# %%
q1
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                  4.800             3.200                1.4
# versicolor              5.600             2.525                4.0
# virginica               6.225             2.800                5.1
#
#             petal width (cm)
# target
# setosa                   0.2
# versicolor               1.2
# virginica                1.8

# %%
IQR = q3 - q1

# %%
IQR
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                  0.400             0.475              0.175
# versicolor              0.700             0.475              0.600
# virginica               0.675             0.375              0.775
#
#             petal width (cm)
# target
# setosa                   0.1
# versicolor               0.3
# virginica                0.5

# %%
minimo = df_total.groupby('target').min()

# %%
minimo
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                    4.3               2.3                1.0
# versicolor                4.9               2.0                3.0
# virginica                 4.9               2.2                4.5
#
#             petal width (cm)
# target
# setosa                   0.1
# versicolor               1.0
# virginica                1.4

# %%
maximo = df_total.groupby('target').max()

# %%
maximo
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                    5.8               4.4                1.9
# versicolor                7.0               3.4                5.1
# virginica                 7.9               3.8                6.9
#
#             petal width (cm)
# target
# setosa                   0.6
# versicolor               1.8
# virginica                2.5

# %%
rango = maximo - minimo

# %%
rango
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                    1.5               2.1                0.9
# versicolor                2.1               1.4                2.1
# virginica                 3.0               1.6                2.4
#
#             petal width (cm)
# target
# setosa                   0.5
# versicolor               0.8
# virginica                1.1

# %%
# 5
df_total.groupby('target').describe()
# Out:
#            sepal length (cm)                                              \
#                        count   mean       std  min    25%  50%  75%  max
# target
# setosa                  50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor              50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica               50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal width (cm)         ... petal length (cm)       \
#                       count   mean  ...               75%  max
# target                              ...
# setosa                 50.0  3.428  ...             1.575  1.9
# versicolor             50.0  2.770  ...             4.600  5.1
# virginica              50.0  2.974  ...             5.875  6.9
#
#            petal width (cm)
#                       count   mean       std  min  25%  50%  75%  max
# target
# setosa                 50.0  0.246  0.105386  0.1  0.2  0.2  0.3  0.6
# versicolor             50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica              50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5
#
# [3 rows x 32 columns]

# %%
# 6
df_total.set_index(['target', 'petal width (cm)'], inplace=False)
# Out:
#                             sepal length (cm)  sepal width (cm)  \
# target    petal width (cm)
# setosa    0.2                             5.1               3.5
#           0.2                             4.9               3.0
#           0.2                             4.7               3.2
#           0.2                             4.6               3.1
#           0.2                             5.0               3.6
# ...                                       ...               ...
# virginica 2.3                             6.7               3.0
#           1.9                             6.3               2.5
#           2.0                             6.5               3.0
#           2.3                             6.2               3.4
#           1.8                             5.9               3.0
#
#                             petal length (cm)
# target    petal width (cm)
# setosa    0.2                             1.4
#           0.2                             1.4
#           0.2                             1.3
#           0.2                             1.5
#           0.2                             1.4
# ...                                       ...
# virginica 2.3                             5.2
#           1.9                             5.0
#           2.0                             5.2
#           2.3                             5.4
#           1.8                             5.1
#
# [150 rows x 3 columns]

# %% [markdown]
# <font color='green'>Fin Actividad 2</font>

# %% [markdown]
# ## <font color='blue'>**Análisis de Datos con Base de Datos Titanic**</font>
#
# Para este probleme utilizaremos la base de datos "_titanic_". Para cargarla debe usar los siguientes comandos:
#
# ```
# import seaborn as sns
# titanic = sns.load_dataset("titanic")
# titanic.head(5)
# ```
# Considere sólo las siguientes variables: _survived_, _pclass_, _sex_, _age_, _fare_ y _embarked_.

# %% [markdown]
# ### <font color='green'>Actividad 3</font>
#
# 1. Reemplace los valores faltantes para la columna edad por el valor promedio de la muestra.
# 2. Elimine cualquier otra fila en la que falten datos

# %%
# Tu código aquí ...
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['age'].fillna(value = titanic['age'].mean(), inplace = True)

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.dropna(inplace = True)

# %%
titanic.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# <font color='green'>Fin Actividad 3</font>

# %% [markdown]
# ### <font color='green'>Actividad 4</font>
#
# 1. Entregar la información correspondiente a la la tasa de supervivencia promedio agrupada por sexo y clase del pasajero.
# 2. Genere una tabla que muestre la cantidad de personas agrupadas por sexo y clase.
# 3. Muestre la misma información del punto 1, pero la cantidad de sobrevivientes.

# %%
#1, 2 y 3
agrupado = titanic.groupby(by= ['sex', 'class'])

print(agrupado['survived'].agg(['mean', 'count', 'sum']))
# Out:
#                    mean  count  sum
# sex    class
# female First   0.962025     79   76
#        Second  0.900000     10    9
#        Third   0.666667      6    4
# male   First   0.414894     94   39
#        Second  0.666667      6    4
#        Third   0.333333      6    2

# %% [markdown]
# Hasta ahora hemos examinado las tasas de supervivencia según el sexo y la clase de pasajeros. Otro factor que podría haber influido en la supervivencia es la edad. **¿Los niños varones tenían tanta probabilidad de morir como las mujeres en general?** Podemos investigar esta pregunta mediante la indexación múltiple, o pivotando en más de dos variables, agregando otro índice.
#
# Divida la información de la columna "age" en intervalos, creando así una nueva categoría que se puede utilizar para agrupar. Divida el conjunto en intervalos de (0, 12], (12, 18] y (18, 80].
#
# 4. Genere la tabla que le ayude a responder la pregunta anterior (considerando los rangos definidos).
# 5. Para una mejor interpretación de la información anterior, genere una tabla con el número de entradas por cada grupo.

# %%
# Tu código aquí ...
rangos = [0,12,18,80]
etiquetas = ['Niño', 'Joven', 'Adulto']
titanic['rango_etario'] = pd.cut(titanic['age'], bins = rangos, labels = etiquetas)

# %%
#4 y 5
agrupado = titanic.groupby(by= ['sex', 'rango_etario'])

print(agrupado['survived'].agg(['mean', 'count', 'sum']))
# Out:
#                          mean  count  sum
# sex    rango_etario
# female Niño          0.500000      4    2
#        Joven         1.000000     10   10
#        Adulto        0.950617     81   77
# male   Niño          1.000000      7    7
#        Joven         0.500000      2    1
#        Adulto        0.381443     97   37

# %% [markdown]
# Pandas también admite la indexación múltiple en las columnas. Como ejemplo, considere el precio de los boletos de un pasajero. Esta es otra característica continua que se puede discretizar. Divida los precios en 2 cuantiles iguales (baratos y caros). Algunos de los grupos resultantes podrían estar vacíos; para mejorar la legibilidad de la tabla use un guión en las casillas vacías.
#
# 6. Genere una tabla que nos permita ver el efecto del precio de los tickets.

# %%
# Tu código aquí ...
titanic['fare'].describe()
# Out:
# count    201.000000
# mean      76.305307
# std       74.891320
# min        0.000000
# 25%       28.712500
# 50%       55.000000
# 75%       90.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
rangos = [0,55,520]
etiquetas = ['Barato', 'Caro']

titanic['valor_pasaje'] = pd.cut(titanic['age'], bins = rangos, labels = etiquetas)

# %%
#6
agrupado = titanic.groupby(by= ['sex', 'rango_etario', 'valor_pasaje'])

print(agrupado['survived'].agg(['mean', 'count', 'sum']).fillna('-'))
# Out:
#                                       mean  count  sum
# sex    rango_etario valor_pasaje
# female Niño         Barato             0.5      4    2
#                     Caro                 -      0    0
#        Joven        Barato             1.0     10   10
#                     Caro                 -      0    0
#        Adulto       Barato        0.959459     74   71
#                     Caro          0.857143      7    6
# male   Niño         Barato             1.0      7    7
#                     Caro                 -      0    0
#        Joven        Barato             0.5      2    1
#                     Caro                 -      0    0
#        Adulto       Barato        0.409639     83   34
#                     Caro          0.214286     14    3

# %% [markdown]
# <font color='green'>Fin Actividad 4</font>

# %% [markdown]
# ### <font color='green'>Actividad 5</font>
#
# ### Análisis de una Hipótesis
#
# Supongamos que alguien afirma que la ciudad desde la que se embarcó un pasajero tuvo una gran influencia en la tasa de supervivencia del pasajero. Investigue esta afirmación.
#
# 1. Verifique las tasas de supervivencia de los pasajeros según el lugar desde donde se embarcaron (indicadas en la columna "embarked").
#
# 2. Cree una tabla dinámica para examinar las tasas de supervivencia según el lugar de embarque y el género.
#
# 3. ¿Qué le sugieren estas tablas sobre la importancia de dónde se embarcaron las personas para influir en su tasa de supervivencia? Examine el contexto del problema y explique lo que cree que esto realmente significa.
#
# 4. Investigue la afirmación más a fondo con al menos dos tablas dinámicas más, explorando otros criterios (por ejemplo, clase, edad, etc.). Explique cuidadosamente sus conclusiones.

# %%
# Tu código aquí ...

# 1 y 2
embarque = titanic.groupby(by= ['embarked'])

print(embarque['survived'].agg(['mean', 'count', 'sum']))
print()

agrupado = titanic.groupby(by= ['embarked', 'sex'])

print(agrupado['survived'].agg(['mean', 'count', 'sum']))
# Out:
#               mean  count  sum
# embarked
# C         0.753623     69   52
# Q         0.500000      4    2
# S         0.625000    128   80
#
#                      mean  count  sum
# embarked sex
# C        female  0.972973     37   36
#          male    0.500000     32   16
# Q        female  1.000000      2    2
#          male    0.000000      2    0
# S        female  0.910714     56   51
#          male    0.402778     72   29

# %% [markdown]
# Se observa que aquellas personas que embarcaron en Cherbourg tienen en promedio una mayor tasa de supervivencia que aquellas que embarcaron en Southampton.
#
# No se cuentan con suficientes datos de Queenstown como para generalizar.

# %%
#4

agrupado = titanic.groupby(by= ['embarked', 'class'])

print(agrupado['survived'].agg(['mean', 'count', 'sum']))
print()

agrupado = titanic.groupby(by= ['embarked', 'rango_etario'])

print(agrupado['survived'].agg(['mean', 'count', 'sum']).fillna('-'))
# Out:
#                      mean  count  sum
# embarked class
# C        First   0.757576     66   50
#          Second  0.500000      2    1
#          Third   1.000000      1    1
# Q        First   0.500000      2    1
#          Second  1.000000      1    1
#          Third   0.000000      1    0
# S        First   0.609524    105   64
#          Second  0.846154     13   11
#          Third   0.500000     10    5
#
#                            mean  count  sum
# embarked rango_etario
# C        Niño                 -      0    0
#          Joven         0.833333      6    5
#          Adulto        0.746032     63   47
# Q        Niño                 -      0    0
#          Joven                -      0    0
#          Adulto             0.5      4    2
# S        Niño          0.818182     11    9
#          Joven              1.0      6    6
#          Adulto        0.585586    111   65

# %% [markdown]
# Al generar estas tablas por clase y rango etario podemos observar que en Cherbourg asistieron principalmente personas en primera clase, mientras que en Southampton existe un mayor porcentaje de personas en segunda y tercera clase.

# %% [markdown]
# Las letras que etiquetan las categorías de la variable 'embarked' corresponden a las ciudades donde la gente se embarcó en el Titanic:
#
# * Cherbourg
# * Queenstown
# * Southampton

# %% [markdown]
# <font color='green'>Fin Actividad 5</font>
